# %% [markdown]
# ###### 1. load the iris.csv dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.style.use('bmh')

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# #### 1. create a bar plot for count the frequency of the three species.

# %%
### code here

# %%
df1 = plt.subplots(1,1,figsize=(10,8))
sns.countplot('Species',data=df)
plt.title("Iris Species Count")
plt.show()

# %% [markdown]
# ##### 2. Create a pie chart to show the percentage of species.

# %%
### code here

# %%
plt.pie(x = df.Species.value_counts().values,
       labels = df.Species.value_counts().
       index,autopct= '%.2f%%');

# %% [markdown]
# ##### 3. Create the joint to all numberical variable for analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
### code here

# %%
sns.jointplot(data = df, x ='SepalLengthCm',y = 'SepalWidthCm');

# %% [markdown]
# ##### 4. Create a scatter plot and take hue = "Species"

# %%
### code here

# %%
sns.scatterplot(data = df,x ='PetalLengthCm',y ='PetalWidthCm',hue="Species")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# ###### 5. Create a Boxplot or Whisker plot as univeriate and bivariate analysis.

# %%
### code here

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data= df,x = 'SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
sns.boxplot(x='Species', y='SepalLengthCm' , data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(data=df,x = 'SepalLengthCm',y = 'SepalWidthCm',hue='Species',)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ###### 6. Create a Strip plot

# %%
### code here

# %%
#sns.stripplot(data=df, y='SepalLengthCm',x='Species');
sns.stripplot(data=df, y='PetalLengthCm',x='Species');

# %% [markdown]
# ###### 7. Create a Violin Plot.

# %%
### code here

# %%
#sns.violinplot(data = df,x ='Species', y ='SepalWidthCm')
#sns.violinplot(data = df,x ='Species', y ='PetalWidthCm')
#sns.violinplot(data = df,x ='Species', y ='SepalLengthCm')
sns.violinplot(data = df,x ='Species', y ='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# ##### 8. Create a pair chart.

# %%
### code here

# %%
plt.pie(x = df.Species.value_counts().values,
       labels = df.Species.value_counts().
       index,autopct= '%.2f%%');

# %% [markdown]
# ##### 9. Create a Heat Map

# %%
### code here

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True);

# %% [markdown]
# ###### 10. Create a distribution plot for all numerical colomns.

# %%
### code here

# %%
sns.displot(data = df,x = 'Id');
sns.displot(data = df,x = 'SepalLengthCm');
sns.displot(data = df,x = 'SepalWidthCm');
sns.displot(data = df,x = 'PetalLengthCm');
sns.displot(data = df,x = 'PetalWidthCm');

# %%
# second step of all numerical column distribution

df.hist(edgecolor='black',bins = 25, figsize= (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)
