# %% [markdown]
# ##### import required libraries.
# ##### laod diamond dataset

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('diamonds')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# #### Write a Python program to display all Univariate Plots from the dataframe.
#
#
# 1.   Numeric based plots
# 2.   Categorical based plots

# %%
#### code here

# %%
#### code here

# %%
sns.distplot(df['carat'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
sns.histplot(x = df['carat'])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Count'>

# %%
sns.countplot(data=df, x = 'cut')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
df["color"].value_counts().plot.pie(autopct="%.2f%%",);

# %%
sns.countplot(data=df, x = 'clarity')
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='count'>

# %%
# sns.displot(df.price,kind='kde')
sns.boxplot(df.price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.distplot(df["depth"])
plt.title('Histogram of Depth')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#df.boxplot(column="table")
sns.boxplot(x='table',data=df)
# Out:
# <AxesSubplot:xlabel='table'>

# %%
sns.violinplot(df["x"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x'>

# %% [markdown]
# #### Write a Python program to display all Bivariate plots from the dataframe.
#
# 1.   Numeric to Numeric based plots
# 2.   Numeric to Categorical Plots
# 3.   Categorical to Categorical Plots

# %% [markdown]
# * Numerical and Numerical Varible:
#
#     * Scatterplot
#     * heatmap
#     * pairplot
#     * regplot
#     * relplot
# * Numerical and Categorical variable:
#
#     * Boxplot
#     * Barplot
#     * Violinplot
#     * Scatterplot
#     * Lineplot
#     * Swarmplot
# * Categorical and Categorical variables:
#
#     * Crosstab then draw the barplot

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ### 1.numerical to numerica

# %%
### code here
sns.scatterplot(x=df.table,y=df.depth)
# Out:
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
### code here
sns.pairplot(data =df,hue='cut')

# %%
#### code here
sns.heatmap(df.corr(),data=df,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(df.carat,df.price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.relplot(df.carat,df.price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
### code here

# %% [markdown]
# * Numerical and Categorical variable:
#     * Boxplot
#     * Barplot
#     * Violinplot
#     * Scatterplot
#     * Lineplot
#     * Swarmplot

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.boxplot(x=df.cut,y=df.price)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.barplot(data=df, x=df.cut,y=df.price,hue='color')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.violinplot(data=df, x=df.color,y=df.table)
# Out:
# <AxesSubplot:xlabel='color', ylabel='table'>

# %%
sns.scatterplot(data=df, x=df.clarity,y=df.depth,hue='cut')
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='depth'>

# %%
sns.lineplot(x=df.cut,y=df.table,hue='color',data=df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='table'>

# %%
#### code here

# %% [markdown]
# * Categorical and Categorical variables:
#     * Crosstab then draw the barplot

# %%
crosstab=pd.crosstab(df.cut,df.color)

# %%
crosstab.plot(kind="bar",stacked=True)
# Out:
# <AxesSubplot:xlabel='cut'>

# %% [markdown]
# #### Write a Python program to display all Multivariate plots from the dataframe.

# %% [markdown]
# multivariate plots
#
#     * pairplot
#
#     * heatmap

# %%
### code here
#sns.pairplot(df,kind='kde',hue='cut',data=df)

# %%
### code here

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### hint - https://www.python-graph-gallery.com/
